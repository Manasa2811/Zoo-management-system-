# %%
from tkinter import *
import psycopg2
# postgresql-cubic-98264

root = Tk()
root.title('Zoo Management System')
#root.iconbitmap('c:/gui/codemy.ico')
root.geometry("500x550")

def clear():
	f_name.delete(0, END)
	_name.delete(0, END)

def query():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)



def q1():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("SELECT * FROM animal")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]} {record[2]} {record[3]} {record[4]}')
		output = output_label['text']

	conn.close()


def q2():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("SELECT * FROM employee")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]} {record[2]} {record[3]} {record[4]} {record[5]}')
		output = output_label['text']

	conn.close()

def q3():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("SELECT * FROM customer")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]} {record[2]} {record[3]} {record[4]} {record[5]} ')
		output = output_label['text']

	conn.close()
    
def q4():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select eid, efname, elname from employee where salary > 5000;")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]} {record[2]}')
		output = output_label['text']

	conn.close()
    
    
def q5():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select * from customer where address = 'bangalore';")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]} {record[2]} {record[3]} {record[4]} {record[5]}')
		output = output_label['text']

	conn.close()
    
def q6():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select aid from animal where gender = 'female';")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]}')
		output = output_label['text']

	conn.close()
    
def q7():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select EFname, sum(salary) as total_salary from Employee group by (EFName)")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]}')
		output = output_label['text']

	conn.close()
    
def q8():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select cid, cfname, clname, email from customer where cid in ( select cid from ticket where tid = '4');")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]} {record[2]} {record[3]}')
		output = output_label['text']

	conn.close()
    
def q9():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select akid, aname from animal_kind where akid in (select akid from animal where cage_number = '1');")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]}')
		output = output_label['text']

	conn.close()
    
def q10():
	# Configure and connect to Postgres
	conn = psycopg2.connect(
		host = "::1", 
		database = "postgres",
		user = "postgres",
		password = "manasa", 
		port = "5432",
		)

	# Create a cursor
	c = conn.cursor()

	# Grab stuff from online database
	c.execute("select hours, location from zoo where zid = '1015';")
	records = c.fetchall()

	output = ''

	# Loop thru the results
	for record in records:
		output_label.config(text=f'{output}\n{record[0]} {record[1]}')
		output = output_label['text']

	conn.close()
    
    
def remove_text():
    output_label.config(text="")
    

    

# Create The GUI For The App

my_frame = LabelFrame(root, text="Select a query", bg='mistyrose2')
my_frame.pack(pady=20)

clear_button=Button(my_frame, text="CLEAR", command=remove_text, bg="light blue")
clear_button.grid(row=6, column=2, pady=10, padx=10)



q1_button = Button(my_frame, text="query 1", command=q1)
q1_button.grid(row=2, column=0, pady=10, padx=10)

q2_button = Button(my_frame, text="query 2", command=q2)
q2_button.grid(row=2, column=1, pady=10, padx=10)

q3_button = Button(my_frame, text="query 3", command=q3)
q3_button.grid(row=2, column=2, pady=10, padx=10)

q4_button = Button(my_frame, text="query 4", command=q4)
q4_button.grid(row=2, column=3, pady=10, padx=10)

q5_button = Button(my_frame, text="query 5", command=q5)
q5_button.grid(row=2, column=4, pady=10, padx=10)

q6_button = Button(my_frame, text="query 6", command=q6)
q6_button.grid(row=4, column=0, pady=10, padx=10)

q7_button = Button(my_frame, text="query 7", command=q7)
q7_button.grid(row=4, column=1, pady=10, padx=10)

q8_button = Button(my_frame, text="query 8", command=q8)
q8_button.grid(row=4, column=2, pady=10, padx=10)

q9_button = Button(my_frame, text="query 9", command=q9)
q9_button.grid(row=4, column=3, pady=10, padx=10)

q10_button = Button(my_frame, text="query 10", command=q10)
q10_button.grid(row=4, column=4, pady=10, padx=10)

output_label = Label(root, text="", bg='white', height=30, width=50)
output_label.pack(pady=50)





query()

root.mainloop()
